# %%
###################################################
# STILL MISSING
#
# - Mass functions
###################################################

# %%
using Pkg
Pkg.activate("./")
Pkg.instantiate()

using DelimitedFiles
using Integrals
using Interpolations
using Trapz
using SciPy
using LaTeXStrings
# Out:
#   Activating project at `~/Nextcloud/Promotion/OP3PGN/Evaporation/DarkMatterProduction`

# %%
#Loading the code...

include("Code/units.jl") #Units and definitions
include("Code/data.jl") #Data from BlackHawk, Constraints and others
include("Code/interpolation.jl") #Routines for interpolation
include("Code/cosmology.jl") #Cosmological background
include("Code/technical.jl") #Some stuff...
include("Code/evaporation.jl") #Main module which contains the evaporation physics
include("Code/constraints.jl") #Functions to obtain constraints on f_PBH
# Out:
# constraint_k_bbn_ext (generic function with 1 method)

# %%
#BLACK HOLE PARAMETERS

m0s = 1e1*ones(20) #BH mass in gram
ks = LinRange(0.01,0.5,20) #Burden exponent
qs = 0.5*ones(20) #Burden q (when memory burden sets in)
bursts = falses(20) #Whether T~const. or T~1/M during memory burden
a_bh = 0.0 #Value of initial BH spin parameter
two_stages = true #Whether to include two stages of the evaporation (does not work with fit!)

#PARTICLE DM PARAMETERS
T2_ncdm = 0.69054 * (qs*m/mp).^(1/2) .* sqrt.((1 .- qs.^3)./qs.^3 .+ 12.567.^(ks) .* (qs*m/mp).^(2*ks) * 3)
p2_rms = 3.23280617733076
Ω2 = 0.12 * 2 * qs.^2 ./ (1 .+ qs.^2)

T1_ncdm = 0.69054 * (1 .- qs.^3).^(1/2) *(m/mp)^(1/2)
p1_rms = 5.057163286675063
Ω1 = 0.12 * (1 .- q.^2) ./ (1 .+ q^2)

m_ncdms = 1e-6*1.75*5.3^(4/3).*sqrt.(Ω1/Ω*p1_rms^2 .*T1_ncdm.^2 .+ Ω2/Ω*p2_rms^2 .*T2_ncdm.^2)

#m_ncdms = 1*ones(20) #DM mass in GeV
s = 0.5 #Spin of DM particle
g = 1 #DOF of DM particle

#COMOLOGICAL PARAMETERS

#Specify one of the following three parameters:
β = nothing #Initial PBH density fraction. If set to nothing, f is used.
f = nothing #Initial PBH dark matter fraciton. If set to nothing then Ω_ncdm is used.
Ω_ncdm = 0.12 #If set to nothing, then it is computed.
md = nothing #If set to nothing, then it is computed whether there is matter domination phase.

Ω_dm = 0.1201075 #Total dark matter density

#PSD PARAMETERS

use_fits = falses(20) #Whether to use a PSD file or an analytical expression

n_e_class = 200 #Number of values for q=E/T for CLASS
q_min_class = 0.01 #Minimum value for q=E/T for CLASS
q_max_class = 100 #Maximum value for q=E/T for CLASS
#qs_max_class = [10,100,1000,10000,100000] 
n_e = 1000 #Number of values for q=E/T for plots and fitting
q_min = 1e-4 #Minimum value for q=E/T for plots and fitting
q_max = 1e4 #Maximum value for q=E/T for plots and fitting
# Out:
# 10000.0

# %%
using PyPlot
rcdefaults()
rc("figure",dpi=300,figsize=(4,3))
rc("font",size=12,family="serif",serif="cmr10")
rc("mathtext",fontset="cm")
rc("axes",unicode_minus=false)
rc("xtick",direction="in",top=true)
rc("ytick",direction="in",right=true)
rc("savefig",bbox="tight")
ion()

area = zeros(length(m0s))
    
pbhini = open("PBH.ini")
pbh_ini_string = read(pbhini,String)
close(pbhini)
run(`mkdir -p Plots`)
run(`mkdir -p Output`)

for i=1:length(m0s)

    parameters = []
    
    m0 = m0s[i]
    q = qs[i]
    k = ks[i]
    m_ncdm = m_ncdms[i]
    burst = bursts[i]
    use_fit = use_fits[i]
    #q_max_class = qs_max_class[i]
    #n_e_class_2 = Int(round(log(q_max_class/q_min_class)/log(qs_max_class[1]/q_min_class)*n_e_class))

    println()
    println()
    println("m=",m0,"g, q=",q,", k=",k,", burst=",burst,", m_dm=",m_ncdm," GeV")
    
    T0 = bh_temp(m0)

    e = 10 .^ LinRange(log10(T0*q_min),log10(T0*q_max),n_e)
    e_class = 10 .^ LinRange(log10(T0*q_min_class),log10(T0*q_max_class),n_e_class)
    println(e_class[1:2])

    t_start = bh_formation(m0)
    if k > 0
        t_end = bh_lifetime_estimate(m0,a_bh,m_fin=q*m0)
    else
        t_end = bh_lifetime_estimate(m0,a_bh)
    end
    #t_end = bh_lifetime_estimate(m0,a_bh,k=k,burst=burst,q=q)
    
    β_c = t_to_a(t_start)/t_to_a(t_end)
    
    if isnothing(md)
        if !isnothing(β)
            β_comp = β
        elseif !isnothing(f)
            β_comp = β_fm(f,m0)
        else
            if burst
                N_approx = 2.85e-2*m0^2/mp^2
            else
                N_approx = 2.85e-2*m0^2/mp^2 * (1+q^2)
            end
            f_comp = Ω_ncdm * m0 / (N_approx * m_ncdm * GeV_to_g * Ω_dm)
            β_comp = β_fm(f_comp,m0)
        end
        if β_comp > β_c
            md_comp = true
        else
            md_comp = false
        end
    else
        md_comp = md
        f_comp = Ω_ncdm * m0 / (N_approx * m_ncdm * GeV_to_g * Ω_dm)
    end
    
    println()
    println("Matter domination: ",md_comp)
    println()
    println("First stage")

    a_end = t_to_a(t_end)
    #a_end = 2.2e-31 * (m0/mp)^(3/2)
    #a_end_approx = 3.33e-31 * (1-q^3)^(1/2)*(m0/mp)^(3/2)
    #println("aev_1 ",abs(1-a_end/a_end_approx))
    if md_comp
        a_end = a_end*(9/16)^(1/4)
    end
    
    T_ncdm = T0*GeV_to_K/2.7255*a_end
    println("T_ncdm ",T_ncdm)
    #T_ncdm_approx = 0.69054 * (1-0*q^3)^(1/2) *(m0/mp)^(1/2)
    #println("T_ncdm_approx ",T_ncdm_approx)
    

    
    Φ1, Φ2 = spectrum_redshift(e,m0,s,g,a_bh,
        t_start=t_start,t_end=t_end,go=false,k=k,burst=burst,q=q,instant=false,n_steps=1000,split_flux=true,md=md_comp)
    Φ1_class, Φ2_class = spectrum_redshift(e_class,m0,s,g,a_bh,
        t_start=t_start,t_end=t_end,go=false,k=k,burst=burst,q=q,instant=false,n_steps=1000,split_flux=true,md=md_comp)
    
    N1 = trapz(e,Φ1)
    println(N1)
    #N1_approx = 2.85e-2*m0^2/mp^2*(1-q^2)
    #println("N_1 ",abs(1-N1/N1_approx))
    
    if !isnothing(β)
        if β < β_c
            Ω1 = N1 * m_ncdm * GeV_to_g * Ω_dm * f_βm(β,m0) / m0
            if k > 0
                Ω1_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * Ω_dm * f_βm(β,m0) * (1 - q^2)
            else
                Ω1_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * Ω_dm * f_βm(β,m0)
            end
            #println("Deviation of Ω_ncdm ",round(100*abs(1-Ω1_approx/Ω1),sigdigits=4)," %")
        else
            Ω1 = Ω_dm * m_ncdm*1e3 / sqrt(m0/(1.1e7*mp)) * 2.85/3.2
            if k > 0
                Ω1 *= (1-q^2)
            end
        end
    elseif !isnothing(f)
        Ω1 = N1 * m_ncdm * GeV_to_g * Ω_dm * f / m0
        if k > 0
            Ω1_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * Ω_dm * f * (1 - q^2)
        else
            Ω1_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * Ω_dm * f
        end
        #println("Deviation of Ω_ncdm ",round(100*abs(1-Ω1_approx/Ω1),sigdigits=4)," %")
    elseif burst
        if k > 0
            Ω1 = Ω_ncdm * (1-q^2)
        else 
            Ω1 = Ω_ncdm
        end
        f_check = Ω1 * m0 / (N1 * m_ncdm * GeV_to_g * Ω_dm)
        if abs(1-f_check/f_comp) > 1e-3
            throw(ArgumentError("Something with the PBH abundance is not right..."))
        end
        println("f_PBH: ",f_comp)
    else
        if k > 0
            Ω1 = Ω_ncdm * (1-q^2)/(1+q^2)
        else
            Ω1 = Ω_ncdm
        end
        f_check = Ω1 * m0 / (N1 * m_ncdm * GeV_to_g * Ω_dm)
        if abs(1-f_check/f_comp) > 1e-3
            throw(ArgumentError("Something with the PBH abundance is not right..."))
        end
        println("f_PBH: ",f_comp)
    end
    
    if bh_lifetime_estimate(m0,k=k,burst=burst,q=q) > 1 && f_comp > 1
        println("Ω_PBH>1 today!")
    end
    
    println("Ω_ncdm ",Ω1)
    
    if use_fit
        ff(x,a,b,c,d,e) = spectrum_redshift_approximation.(x,bh_lifetime_estimate(m0,a_bh,m_fin=q*m0),bh_lifetime_estimate(m0,a_bh,k=k,burst=burst,q=q),a,b,c,d,e)
        fit = optimize.curve_fit(ff,e/T0,Φ1*T0^3/(mp*g_to_GeV)^2,[1,1,1,1,1])
        Φ_fit = ff.(e/T0,fit[1]...)


        p_mean = trapz(e/T0,e/T0 .* Φ1)/trapz(e/T0,Φ1)
        println("Mean momentum: ",p_mean)
        p_mean_approx = trapz(e/T0,e/T0  .* Φ_fit)/trapz(e/T0,Φ_fit)
        p_mean1_err = round(100*abs(1-p_mean_approx/p_mean),sigdigits=4)
        println("Deviation of mean momentum: ",p_mean1_err," %")

        p_rms = sqrt(trapz(e/T0,(e/T0).^2 .* Φ1)/trapz(e/T0,Φ1))
        println("RMS momentum: ",p_rms)
        p_rms_approx = sqrt(trapz(e/T0,(e/T0).^2  .* Φ_fit)/trapz(e/T0,Φ_fit))
        p_rms1_err = round(100*abs(1-p_rms_approx/p_rms),sigdigits=4)
        println("Deviation of rms momentum: ",p_rms1_err," %")
        flush(stdout)

        fig = figure(figsize=(8,3))
        ax = subplot(121)
        p = loglog(e/T0, (T0^3/(mp*g_to_GeV)^2)*Φ1,"--")
        plot(e_class/T0, (T0^3/(mp*g_to_GeV)^2)*Φ1_class,color=p[1].get_color())
        plot(e/T0,Φ_fit,"-.",color="black")
        ylim(1e-20,1e5)
        xlim(q_min,q_max)
        grid()
        xlabel(L"q = E/T_F")
        title(L"%$(i) | First stage at $t_{\rm ev,1}$")

        ax = subplot(122)
        plot(e_class/T0, (T0^3/(mp*g_to_GeV)^2)*Φ1_class)
        plot(e/T0,Φ_fit,"-.",color="black")
        ylim(0,maximum((T0^3/(mp*g_to_GeV)^2)*Φ1_class)*1.3)
        xlim(0,20)
        grid()
        xlabel(L"q = E/T_F")
        show()
        savefig(string("Plots/",i,"_sc.png"))
    else
        fit = [[0,0,0,0,0]]
    end
    
    writedlm(string("Input/psd_",i,"_sc.dat"),[e_class/T0 (T0^3/(mp*g_to_GeV)^2)*Φ1_class/1.0./ (e_class/T0).^2])
    
    if two_stages && k > 0
        
        println()
        println("Second stage")
        
        T0 = T0/q

        t_end2 = bh_lifetime_estimate(m0,a_bh,k=k,burst=burst,q=q)

        a_end2 = t_to_a(t_end2)
        #if burst
        #    a_end2_approx = 3.336e-31 * 12.567^(k/2) * q^(3/2+k) * (m0/mp)^(3/2+k) / sqrt(1+2/3*k)
        #else
        #    a_end2_approx = 3.336e-31 * 12.567^(k/2) * q^(3/2+k) * (m0/mp)^(3/2+k) * sqrt(3)
        #end
        #println("aev_2 ",abs(1-a_end2/a_end2_approx))
        if md_comp
            a_end2 = a_end2*(9/16)^(1/4)
        end


        T_ncdm2 = T0*GeV_to_K/2.7255*a_end2
        println("T_ncdm2 ",T_ncdm2)
        #if burst
        #    T_ncdm2_approx = 0.6905 * 12.567^(k/2) * q^(1/2+k) * (m0/mp)^(1/2 + k) / sqrt(1 + 2/3*k)
        #else
        #    T_ncdm2_approx = 0.6905 * 12.567^(k/2) * q^(1/2+k) * (m0/mp)^(1/2 + k) * sqrt(3)
        #end
        #println("Tncdm_2 ",abs(1-T_ncdm2/T_ncdm2_approx))


        Φ1, Φ2 = spectrum_redshift(e,m0,s,g,a_bh,
            t_start=t_start,t_end=t_end2,go=false,k=k,burst=burst,q=q,instant=false,n_steps=1000,split_flux=true,md=md_comp)
        Φ1_class, Φ2_class = spectrum_redshift(e_class,m0,s,g,a_bh,
            t_start=t_start,t_end=t_end2,go=false,k=k,burst=burst,q=q,instant=false,n_steps=1000,split_flux=true,md=md_comp)
        
        
        N2 = trapz(e,Φ2)
        #if burst
        #    N2_approx = 2.85e-2*m0^2/mp^2*q^2
        #else
        #    N2_approx = 2.85e-2*2*m0^2/mp^2*q^2
        #end
        #Ntot_approx = 2.85e-2*m0^2/mp^2*(1+q^2)

        if !isnothing(β)
            if β < β_c
                Ω2 = N2 * m_ncdm * GeV_to_g * 0.26 * f_βm(β,m0) / m0
                Ω2_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * 0.26 * f_βm(β,m0) * q^2
                if !burst
                    Ω2_approx *= 2
                end
                #println("Deviation of Ω_ncdm ",round(100*abs(1-Ω1_approx/Ω1),sigdigits=4)," %")
            else
                Ω2 = Ω_dm * m_ncdm*1e3 / sqrt(m0/(1.1e7*mp)) * 2.85/3.2 * q^2
                if !burst
                    Ω2 *= 2
                end
            end
        elseif !isnothing(f)
            Ω2 = N2 * m_ncdm * GeV_to_g * 0.26 * f / m0
            Ω2_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * 0.26 * f * q^2
            if !burst
                Ω2_approx *= 2
            end
            #println("Deviation of Ω_ncdm ",round(100*abs(1-Ω1_approx/Ω1),sigdigits=4)," %")
        elseif burst
            Ω2 = Ω_ncdm * q^2
            #Ω2 = Ω_ncdm
        else
            Ω2 = 2 * Ω_ncdm * q^2/(1+q^2)
            #Ω2 = Ω_ncdm
        end

        println("Ω_ncdm2 ",Ω2)
        
        if use_fit
            ff2(x,a,b,c,d,e) = spectrum_redshift_approximation.(x,bh_lifetime_estimate(m0,a_bh,m_fin=q*m0),bh_lifetime_estimate(m0,a_bh,k=k,burst=burst,q=q),a,b,c,d,e)
            fit2 = optimize.curve_fit(ff2,e/T0,Φ2*T0^3/(mp*g_to_GeV)^2,[1,1,1,1,1])
            Φ_fit2 = ff2.(e/T0,fit2[1]...)

            p_mean2 = trapz(e/T0,e/T0 .* Φ2)/trapz(e/T0,Φ2)
            println("Mean momentum: ",p_mean2)
            println(a_end2/(Ω_r_fid/Ω_m_fid))
            println(1e4*a_end2/(Ω_r_fid/Ω_m_fid)*T0*p_mean2)
            p_mean_approx2 = trapz(e/T0,e/T0  .* Φ_fit2)/trapz(e/T0,Φ_fit2)
            p_mean_err2 = round(100*abs(1-p_mean_approx2/p_mean2),sigdigits=4)
            println("Deviation of mean momentum: ",p_mean_err2," %")

            p_rms2 = sqrt(trapz(e/T0,(e/T0).^2 .* Φ2)/trapz(e/T0,Φ2))
            println("RMS momentum: ",p_rms2)
            p_rms_approx2 = sqrt(trapz(e/T0,(e/T0).^2  .* Φ_fit2)/trapz(e/T0,Φ_fit2))
            p_rms_err2 = round(100*abs(1-p_rms_approx2/p_rms2),sigdigits=4)
            println("Deviation of rms momentum: ",p_rms_err2," %")
            flush(stdout)

            fig = figure(figsize=(8,3))
            ax = subplot(121)
            p = loglog(e/T0, (T0^3/(mp*g_to_GeV)^2)*Φ2,"--")
            plot(e_class/T0, (T0^3/(mp*g_to_GeV)^2)*Φ2_class,color=p[1].get_color())
            plot(e/T0,Φ_fit2,"-.",color="black")
            ylim(1e-20,1e5)
            xlim(q_min,q_max)
            grid()
            xlabel(L"q = E/T_F")
            title(L"%$(i) | Second stage at $t_{\rm ev,2}$")

            ax = subplot(122)
            plot(e_class/T0, (T0^3/(mp*g_to_GeV)^2)*Φ2_class)
            plot(e/T0,Φ_fit2,"-.",color="black")
            ylim(0,maximum((T0^3/(mp*g_to_GeV)^2)*Φ2_class)*1.3)
            xlim(0,20)
            grid()
            xlabel(L"q = E/T_F")
            show()
            savefig(string("Plots/",i,"_mb.png"))
        else
            fit2 = [[0,0,0,0,0]]
        end
        writedlm(string("Input/psd_",i,"_mb.dat"),[e_class/T0 (T0^3/(mp*g_to_GeV)^2)*Φ2_class ./(e_class/T0).^2])
    
        push!(parameters,"NNCDM"=>"2")
        push!(parameters,"DEGNCDM"=>"1,1")
        push!(parameters,"MNCDM"=>string(m_ncdm*1e9,",",m_ncdm*1e9))
        push!(parameters,"TNCDM"=>string(T_ncdm,",",T_ncdm2))
        push!(parameters,"OMEGANCDM"=>string(Ω1,",",Ω2))
        push!(parameters,"OMEGACDM"=>string(Ω_dm-Ω1-Ω2))
        push!(parameters,"FITPARAMS"=>string(fit[1][1],",",fit[1][2],",",fit[1][3],",",fit[1][4],",",fit[1][5],
    ",",fit2[1][1],",",fit2[1][2],",",fit2[1][3],",",fit2[1][4],",",fit2[1][5]))
        push!(parameters,"PSDFILE"=>string("../Input/psd_",i,"_sc.dat,../Input/psd_",i,"_mb.dat"))
        println("Using psd file")
        if use_fit
            println("Using fit")
            push!(parameters,"USEFILE"=>"0,0")
        else
            println("Using psd file")
            push!(parameters,"USEFILE"=>"1,1")
        end
    else
        push!(parameters,"NNCDM"=>"1")
        push!(parameters,"DEGNCDM"=>"1")
        push!(parameters,"MNCDM"=>string(m_ncdm*1e9))
        push!(parameters,"TNCDM"=>string(T_ncdm))
        push!(parameters,"OMEGANCDM"=>string(Ω1))
        push!(parameters,"OMEGACDM"=>string(Ω_dm-Ω1))
        push!(parameters,"FITPARAMS"=>string(fit[1][1],",",fit[1][2],",",fit[1][3],",",fit[1][4],",",fit[1][5]))
        push!(parameters,"PSDFILE"=>string("../Input/psd_",i,"_sc.dat"))
        if use_fit
            println("Using fit")
            push!(parameters,"USEFILE"=>"0")
        else
            println("Using psd file")
            push!(parameters,"USEFILE"=>"1")
        end
    end

    push!(parameters,"OUTPUTNAME"=>string(i))
    
    println()
    println("Running CLASS...")

    pbh_ini_string_mod = replace(pbh_ini_string,parameters...)
    open(string("Input/PBH_",i,".ini"), "w") do file
        write(file,pbh_ini_string_mod)
    end

    run(`./run.sh $(i)`)

    println("Computing area criterium...")
    data_cdm = readdlm("Data/CDM00_pk.dat",skipstart=4)
    data_pbh = readdlm(string("Output/",i,"_pk.dat"),skipstart=4)
    cdm_interp = linear_interpolation(log.(data_cdm[:,1]),log.(data_cdm[:,2].*data_cdm[:,1]))
    pbh_interp = linear_interpolation(log.(data_pbh[:,1]),log.(data_pbh[:,2].*data_pbh[:,1]));
    k_ev = 10 .^ LinRange(log10(0.5),log10(20),1000)
    cdm_int = zeros(length(k_ev))
    pbh_int = zeros(length(k_ev))
        
    for i=1:length(k_ev)
        k_int = 10 .^ LinRange(log10(k_ev[i]),log10(500),1000)
        cdm_int[i] = trapz(k_int,exp.(cdm_interp(log.(k_int))))
        pbh_int[i] = trapz(k_int,exp.(pbh_interp(log.(k_int))))
    end
    area[i] = 1 - trapz(k_ev,pbh_int ./ cdm_int)/trapz(k_ev,cdm_int ./ cdm_int)
    println("Area: ",area[i])
    println()
    println("-----------------------------------------------")
    println()
end
# Out:
# m=10.0g, q=0.5, k=0.01, burst=false, m_dm=0.04559857906973137 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.6343059262255528e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1095.132923958517
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_1_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.559858e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000121862
#  -> ncdm species i=2 read from file ../Input/psd_1_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.559858e+07 eV (so m_i / omega_i =4.191517e-06 eV)
#  -> ncdm species i=2 sampled with 33 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000184347
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04431 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775378
#     corresponding to conformal time = 280.649976 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129509
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921963
#     corresponding to conformal time = 286.316085 Mpc
#     with comoving sound horizon rs = 147.071367 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.826499 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.823084 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/1_...
# Computing area criterium...
# Area: 0.3287697514312029
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.035789473684210524, burst=false, m_dm=0.05058937514756917 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.4730766644922126e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1280.1658578058857
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_2_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 5.058938e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.00010984
#  -> ncdm species i=2 read from file ../Input/psd_2_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 5.058938e+07 eV (so m_i / omega_i =2.624059e-06 eV)
#  -> ncdm species i=2 sampled with 38 (resp. 11) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.00018313
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04429 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775377
#     corresponding to conformal time = 280.649977 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129518
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921963
#     corresponding to conformal time = 286.316085 Mpc
#     with comoving sound horizon rs = 147.071367 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.823893 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.820492 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/2_...
# Computing area criterium...
# Area: 0.3231036049933428
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.06157894736842105, burst=false, m_dm=0.05939639113570278 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.2546558229584378e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1589.2319451001747
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_3_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 5.939639e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 9.35535e-05
#  -> ncdm species i=2 read from file ../Input/psd_3_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 5.939639e+07 eV (so m_i / omega_i =1.371555e-06 eV)
#  -> ncdm species i=2 sampled with 35 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000181187
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04427 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775356
#     corresponding to conformal time = 280.649981 Mpc
#     with comoving sound horizon = 144.510123 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129516
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921966
#     corresponding to conformal time = 286.316084 Mpc
#     with comoving sound horizon rs = 147.071367 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.824813 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821407 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/3_...
# Computing area criterium...
# Area: 0.3092661662827567
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.08736842105263157, burst=false, m_dm=0.07404357408690336 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.0064617884823e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 2077.2812492672283
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_4_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 7.404357e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 7.50469e-05
#  -> ncdm species i=2 read from file ../Input/psd_4_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 7.404357e+07 eV (so m_i / omega_i =6.141521e-07 eV)
#  -> ncdm species i=2 sampled with 36 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000178734
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04425 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775342
#     corresponding to conformal time = 280.649983 Mpc
#     with comoving sound horizon = 144.510124 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129496
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921955
#     corresponding to conformal time = 286.316086 Mpc
#     with comoving sound horizon rs = 147.071368 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.826352 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822938 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/4_...
# Computing area criterium...
# Area: 0.2932411589638333
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.1131578947368421, burst=false, m_dm=0.09708887658837284 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 7.675650457577859e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 2815.2798328234917
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_5_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 9.708888e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 5.72335e-05
#  -> ncdm species i=2 read from file ../Input/psd_5_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 9.708888e+07 eV (so m_i / omega_i =2.467225e-07 eV)
#  -> ncdm species i=2 sampled with 40 (resp. 11) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000176318
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04423 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775329
#     corresponding to conformal time = 280.649986 Mpc
#     with comoving sound horizon = 144.510125 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129464
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921926
#     corresponding to conformal time = 286.316092 Mpc
#     with comoving sound horizon rs = 147.071371 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825388 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821979 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/5_...
# Computing area criterium...
# Area: 0.2807104991142976
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.13894736842105262, burst=false, m_dm=0.1318483453863281 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 5.652101873767916e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 3900.182338425396
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_6_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 1.318483e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 4.21449e-05
#  -> ncdm species i=2 read from file ../Input/psd_6_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 1.318483e+08 eV (so m_i / omega_i =9.279258e-08 eV)
#  -> ncdm species i=2 sampled with 62 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000174399
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04422 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775323
#     corresponding to conformal time = 280.649987 Mpc
#     with comoving sound horizon = 144.510126 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129455
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921920
#     corresponding to conformal time = 286.316093 Mpc
#     with comoving sound horizon rs = 147.071371 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.826328 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822914 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/6_...
# Computing area criterium...
# Area: 0.26790485549658194
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.16473684210526315, burst=false, m_dm=0.18286875639112612 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 4.075164586439036e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 5469.208231317337
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_7_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 1.828688e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 3.03865e-05
#  -> ncdm species i=2 read from file ../Input/psd_7_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 1.828688e+08 eV (so m_i / omega_i =3.365085e-08 eV)
#  -> ncdm species i=2 sampled with 69 (resp. 15) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000173093
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.0442 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775303
#     corresponding to conformal time = 280.649991 Mpc
#     with comoving sound horizon = 144.510128 Mpc
#     angular diameter distance = 12.728540 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129475
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921935
#     corresponding to conformal time = 286.316090 Mpc
#     with comoving sound horizon rs = 147.071370 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825394 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821985 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/7_...
# Computing area criterium...
# Area: 0.260195501672863
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.19052631578947368, burst=false, m_dm=0.2565941106244239 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 2.9042766344003945e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 7718.50515151392
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_8_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 2.565941e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 2.16558e-05
#  -> ncdm species i=2 read from file ../Input/psd_8_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 2.565941e+08 eV (so m_i / omega_i =1.197211e-08 eV)
#  -> ncdm species i=2 sampled with 51 (resp. 11) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000172298
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04419 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775309
#     corresponding to conformal time = 280.649990 Mpc
#     with comoving sound horizon = 144.510127 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129450
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921911
#     corresponding to conformal time = 286.316095 Mpc
#     with comoving sound horizon rs = 147.071372 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.82572 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822309 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/8_...
# Computing area criterium...
# Area: 0.25374381443765137
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.2163157894736842, burst=false, m_dm=0.3622372907689922 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 2.0572710182025682e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 10928.359363074693
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_9_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 3.622373e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.53401e-05
#  -> ncdm species i=2 read from file ../Input/psd_9_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 3.622373e+08 eV (so m_i / omega_i =4.217861e-09 eV)
#  -> ncdm species i=2 sampled with 51 (resp. 16) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171839
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04419 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775306
#     corresponding to conformal time = 280.649990 Mpc
#     with comoving sound horizon = 144.510127 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129442
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921916
#     corresponding to conformal time = 286.316094 Mpc
#     with comoving sound horizon rs = 147.071372 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825381 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821972 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/9_...
# Computing area criterium...
# Area: 0.2502240590291631
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.2421052631578947, burst=false, m_dm=0.5129611573874716 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.4527811107700558e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 15498.417813148753
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_10_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 5.129612e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.08327e-05
#  -> ncdm species i=2 read from file ../Input/psd_10_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 5.129612e+08 eV (so m_i / omega_i =1.478797e-09 eV)
#  -> ncdm species i=2 sampled with 200 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171597
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04418 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775304
#     corresponding to conformal time = 280.649991 Mpc
#     with comoving sound horizon = 144.510128 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129433
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921907
#     corresponding to conformal time = 286.316096 Mpc
#     with comoving sound horizon rs = 147.071373 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825503 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822093 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/10_...
# Computing area criterium...
# Area: 0.2477925854592682
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.26789473684210524, burst=false, m_dm=0.7275312597872579 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.0243137596990389e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 21997.560893540493
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_11_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 7.275313e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 7.6378e-06
#  -> ncdm species i=2 read from file ../Input/psd_11_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 7.275313e+08 eV (so m_i / omega_i =5.171850e-10 eV)
#  -> ncdm species i=2 sampled with 68 (resp. 18) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171467
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04418 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775302
#     corresponding to conformal time = 280.649991 Mpc
#     with comoving sound horizon = 144.510128 Mpc
#     angular diameter distance = 12.728540 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129440
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921901
#     corresponding to conformal time = 286.316097 Mpc
#     with comoving sound horizon rs = 147.071373 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825393 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821984 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/11_...
# Computing area criterium...
# Area: 0.24669823473996721
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.2936842105263158, burst=false, m_dm=1.0326570676324474 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 7.216532025678344e14
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 31234.758554052893
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_12_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 1.032657e+09 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 5.38101e-06
#  -> ncdm species i=2 read from file ../Input/psd_12_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 1.032657e+09 eV (so m_i / omega_i =1.806564e-10 eV)
#  -> ncdm species i=2 sampled with 60 (resp. 18) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171398
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04418 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775303
#     corresponding to conformal time = 280.649991 Mpc
#     with comoving sound horizon = 144.510128 Mpc
#     angular diameter distance = 12.728540 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129461
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921926
#     corresponding to conformal time = 286.316092 Mpc
#     with comoving sound horizon rs = 147.071371 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825271 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821862 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/12_...
# Computing area criterium...
# Area: 0.24627229612971413
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.3194736842105263, burst=false, m_dm=1.4663185216997765 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 5.082253746255587e14
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 44359.780492965016
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_13_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 1.466319e+09 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 3.78958e-06
#  -> ncdm species i=2 read from file ../Input/psd_13_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 1.466319e+09 eV (so m_i / omega_i =6.306649e-11 eV)
#  -> ncdm species i=2 sampled with 230 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171365
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04418 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775301
#     corresponding to conformal time = 280.649991 Mpc
#     with comoving sound horizon = 144.510128 Mpc
#     angular diameter distance = 12.728540 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129429
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921899
#     corresponding to conformal time = 286.316098 Mpc
#     with comoving sound horizon rs = 147.071373 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825338 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821929 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/13_...
# Computing area criterium...
# Area: 0.24565067287655806
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.3452631578947368, burst=false, m_dm=2.0824941503501466 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 3.578498791393793e14
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 63006.31525007884
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_14_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 2.082494e+09 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 2.66831e-06
#  -> ncdm species i=2 read from file ../Input/psd_14_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 2.082494e+09 eV (so m_i / omega_i =2.200978e-11 eV)
#  -> ncdm species i=2 sampled with 200 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171348
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04417 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775302
#     corresponding to conformal time = 280.649991 Mpc
#     with comoving sound horizon = 144.510128 Mpc
#     angular diameter distance = 12.728540 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129439
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921911
#     corresponding to conformal time = 286.316095 Mpc
#     with comoving sound horizon rs = 147.071372 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825416 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822007 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/14_...
# Computing area criterium...
# Area: 0.24549739861628495
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.37105263157894736, burst=false, m_dm=2.9578800875241185 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 2.5194404707428422e14
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 89495.31940472669
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_15_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 2.957880e+09 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.87862e-06
#  -> ncdm species i=2 read from file ../Input/psd_15_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 2.957880e+09 eV (so m_i / omega_i =7.680080e-12 eV)
#  -> ncdm species i=2 sampled with 230 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171339
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04417 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775314
#     corresponding to conformal time = 280.649989 Mpc
#     with comoving sound horizon = 144.510127 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129436
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921904
#     corresponding to conformal time = 286.316097 Mpc
#     with comoving sound horizon rs = 147.071373 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825413 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822004 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/15_...
# Computing area criterium...
# Area: 0.24550757145724933
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.3968421052631579, burst=false, m_dm=4.201436613298126 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.773727295212641e14
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 127123.910480811
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_16_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.201437e+09 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.32258e-06
#  -> ncdm species i=2 read from file ../Input/psd_16_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.201437e+09 eV (so m_i / omega_i =2.679676e-12 eV)
#  -> ncdm species i=2 sampled with 40 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171335
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04417 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775317
#     corresponding to conformal time = 280.649988 Mpc
#     with comoving sound horizon = 144.510126 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129448
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921913
#     corresponding to conformal time = 286.316095 Mpc
#     with comoving sound horizon rs = 147.071372 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.82544 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822031 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/16_...
# Computing area criterium...
# Area: 0.24540688349761985
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.4226315789473684, burst=false, m_dm=5.967950591118113 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.2487038366576778e14
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 180575.76327333265
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_17_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 5.967951e+09 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 9.31097e-07
#  -> ncdm species i=2 read from file ../Input/psd_17_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 5.967951e+09 eV (so m_i / omega_i =9.349552e-13 eV)
#  -> ncdm species i=2 sampled with 68 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171335
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04417 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775301
#     corresponding to conformal time = 280.649991 Mpc
#     with comoving sound horizon = 144.510128 Mpc
#     angular diameter distance = 12.728540 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129457
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921921
#     corresponding to conformal time = 286.316093 Mpc
#     with comoving sound horizon rs = 147.071371 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825428 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822019 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/17_...
# Computing area criterium...
# Area: 0.2455634993545056
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.44842105263157894, burst=false, m_dm=8.477301970453425 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 8.790771906069128e13
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 256504.09241430188
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_18_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 8.477302e+09 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 6.55484e-07
#  -> ncdm species i=2 read from file ../Input/psd_18_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 8.477302e+09 eV (so m_i / omega_i =3.261969e-13 eV)
#  -> ncdm species i=2 sampled with 58 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.00017133
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04417 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775312
#     corresponding to conformal time = 280.649989 Mpc
#     with comoving sound horizon = 144.510127 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129427
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921895
#     corresponding to conformal time = 286.316099 Mpc
#     with comoving sound horizon rs = 147.071374 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825411 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822001 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/18_...
# Computing area criterium...
# Area: 0.24536707386487167
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.47421052631578947, burst=false, m_dm=12.041832490776288 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 6.1885953037636305e13
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 364359.78580704133
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_19_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 1.204183e+10 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 4.61453e-07
#  -> ncdm species i=2 read from file ../Input/psd_19_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 1.204183e+10 eV (so m_i / omega_i =1.138077e-13 eV)
#  -> ncdm species i=2 sampled with 30 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171329
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04417 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775308
#     corresponding to conformal time = 280.649990 Mpc
#     with comoving sound horizon = 144.510127 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129454
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921925
#     corresponding to conformal time = 286.316093 Mpc
#     with comoving sound horizon rs = 147.071371 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825438 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822029 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/19_...
# Computing area criterium...
# Area: 0.24530893142579502
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.5, burst=false, m_dm=17.105223204244684 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 4.356682582349097e13
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 517567.7677031423
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_20_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 1.710522e+10 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 3.24856e-07
#  -> ncdm species i=2 read from file ../Input/psd_20_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 1.710522e+10 eV (so m_i / omega_i =3.970658e-14 eV)
#  -> ncdm species i=2 sampled with 30 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171329
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04417 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775302
#     corresponding to conformal time = 280.649991 Mpc
#     with comoving sound horizon = 144.510128 Mpc
#     angular diameter distance = 12.728540 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129420
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921894
#     corresponding to conformal time = 286.316099 Mpc
#     with comoving sound horizon rs = 147.071374 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.82543 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822021 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/20_...
# Computing area criterium...
# Area: 0.24536622412274423
#
# -----------------------------------------------

# %%
data1 = readdlm("../DarkMatterProduction/Scan/only_first.csv")
data2 = readdlm("../DarkMatterProduction/Scan/both_noburst.csv")
data3 = readdlm("../DarkMatterProduction/Scan/both_burst.csv")
data4 = readdlm("../DarkMatterProduction/Scan/sec_noburst.csv")
data5 = readdlm("../DarkMatterProduction/Scan/sec_burst.csv")

plot(data1[1:end-1,5],data1[1:end-1,end],".-",label="1st stage")
plot(data2[1:end-1,5],data2[1:end-1,end],".-",label="Both, no burst")
plot(data3[1:end-1,5],data3[1:end-1,end],".-",label="Both, burst")
plot(data4[1:end-1,5],data4[1:end-1,end],".-",label="2nd stage, no burst")
plot(data5[1:end-1,5],data5[1:end-1,end],".-",label="2nd stage, burst")
#plot(m_ncdms,area)

xscale("log")
xlabel(L"$m_{\rm DM}$ [GeV]")
ylabel(L"A")
ylim(0,1)
xlim(1e-1,1e2)
hlines(0.33,0,1e3,color="black",ls="dashed")
vlines(1.6,0,1,color="gray",ls="dotted")
vlines(11.3487,0,1,color="black",ls="dashed")
vlines(14.7116,0,1,color="black",ls="dotted")
legend(bbox_to_anchor=(1,1))
# Out:
# sys:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x760361063dc0>

# %%
plot(ks,area,".-")

xlabel(L"k")
ylabel(L"A")
ylim(0,0.5)
xlim(0,0.5)
hlines(0.33,0,1e3,color="black",ls="dashed")
vlines(1.6,0,1,color="gray",ls="dotted")
vlines(11.3487,0,1,color="black",ls="dashed")
vlines(14.7116,0,1,color="black",ls="dotted")
legend(bbox_to_anchor=(1,1))
# Out:
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x19ec7c5d0>

# %%
#colors = ["tab:blue","black","tab:orange","tab:green"]

fig = figure()
data_cdm = readdlm("Data/CDM00_pk.dat",skipstart=4)
for i=5
    data_pbh = readdlm(string("Output/",i,"_pk.dat"),skipstart=4)
    plot(log10.(data_pbh[:,1]),data_pbh[:,2]./data_cdm[:,2],
    label=i)
end

xlim(-3,3)
grid()
title("Transfer function")
legend()
show()
#savefig("Plots/transfer.png")
# Out:
# ArgumentError: Cannot open 'Output/5_pk.dat': not a file
#
# Stacktrace:
#  [1] readdlm_auto(input::String, dlm::Char, T::Type, eol::Char, auto::Bool; opts::@Kwargs{skipstart::Int64})
#    @ DelimitedFiles ~/.julia/packages/DelimitedFiles/aGcsu/src/DelimitedFiles.jl:234
#  [2] readdlm_auto
#    @ ~/.julia/packages/DelimitedFiles/aGcsu/src/DelimitedFiles.jl:233 [inlined]
#  [3] readdlm
#    @ ~/.julia/packages/DelimitedFiles/aGcsu/src/DelimitedFiles.jl:170 [inlined]
#  [4] readdlm
#    @ ~/.julia/packages/DelimitedFiles/aGcsu/src/DelimitedFiles.jl:118 [inlined]
#  [5] top-level scope
#    @ ./In[77]:6

# %%
colors = ["tab:blue","black","tab:orange","tab:green"]

fig = figure()
imshow(imread("../Literature/baldes.png"),extent=[-3,3,0,1],aspect="auto")
data_cdm = readdlm("Data/CDM00_pk.dat",skipstart=4)
for i=1:length(m0s)
    data_pbh = readdlm(string("Output/",i,"_pk.dat"),skipstart=4)
    plot(log10.(data_pbh[:,1]),data_pbh[:,2]./data_cdm[:,2],
    label=string(round(m0s[i]/mp,sigdigits=3),L" $M_p$"),color=colors[i],"--")
end

xlim(-3,3)
grid()
title("Transfer function")
legend()
show()
#savefig("Plots/transfer.png")
# Out:
# BoundsError: attempt to access 4-element Vector{String} at index [5]
#
# Stacktrace:
#  [1] getindex(A::Vector{String}, i1::Int64)
#    @ Base ./essentials.jl:13
#  [2] top-level scope
#    @ ./In[28]:8

# %%
colors = ["tab:blue","black","tab:orange","tab:green"]

fig = figure()
imshow(imread("../Literature/baldes.png"),extent=[-3,3,0,1],aspect="auto")
data_cdm = readdlm("Data/CDM00_pk.dat",skipstart=4)
for i=1:length(m0s)
    data_pbh = readdlm(string("Output/",i,"_pk.dat"),skipstart=4)
    plot(log10.(data_pbh[:,1]),data_pbh[:,2]./data_cdm[:,2],
    label=string(round(m0s[i]/mp,sigdigits=3),L" $M_p$"),color=colors[i],"--")
end

xlim(-3,3)
grid()
title("Transfer function")
legend()
show()
savefig("Plots/transfer.png")
# Out:
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)

# %%
writedlm("Output/area_crit.csv",[m0s ks qs bursts m_ncdms use_fits area])


fig = figure()
data_cdm = readdlm("Data/CDM00_pk.dat",skipstart=4)
for i=1:4
    data_pbh = readdlm(string("Output/",i,"_pk.dat"),skipstart=4)
    plot(data_pbh[:,1],data_pbh[:,2],label=string(L"q_{\rm max}=",round(qs_max_class[i],sigdigits=3)))
end

yscale("log")
xscale("log")
xlim(1e0,1e3)
grid()
title("Transfer function")
legend(bbox_to_anchor=(1,1))
show()
savefig("Plots/transfer.png")
# Out:
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)

# %%
plot(qs_max_class,area,".-")
xscale("log")
ylabel("A")
xlabel(L"q_{\rm max}")
# Out:
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# PyObject Text(0.5, 75.85937499999997, '$q_{\\rm max}$')

# %%
#writedlm("Output/area_crit.csv",[m0s ks qs bursts m_ncdms use_fits area])


fig = figure()
data_cdm = readdlm("Data/CDM00_pk.dat",skipstart=4)
for i=1:5
    data_pbh = readdlm(string("Output/",i,"_pk.dat"),skipstart=4)
    plot(data_pbh[:,1],data_pbh[:,2]./data_cdm[:,2],label=string(L"q_{\rm max}=",round(qs_max_class[i],sigdigits=3)))
end

#yscale("log")
xscale("log")
xlim(1e0,1e3)
grid()
title("Transfer function")
legend(bbox_to_anchor=(1,1))
show()
savefig("Plots/transfer.png")
# Out:
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)

# %%
#BLACK HOLE PARAMETERS

m0s = 1e1*ones(10) #BH mass in gram
ks = LinRange(0.01,0.3,10) #Burden exponent
qs = 0.5*ones(10) #Burden q (when memory burden sets in)
bursts = falses(10) #Whether T~const. or T~1/M during memory burden
a_bh = 0.0 #Value of initial BH spin parameter
two_stages = true #Whether to include two stages of the evaporation (does not work with fit!)

#PARTICLE DM PARAMETERS
T2_ncdm = 0.69054 * (qs*m/mp).^(1/2) .* sqrt.((1 .- qs.^3)./qs.^3 .+ 12.567.^(ks) .* (qs*m/mp).^(2*ks) * 3)
p2_rms = 3.23280617733076
Ω2 = 0.12 * 2 * qs.^2 ./ (1 .+ qs.^2)

T1_ncdm = 0.69054 * (1 .- qs.^3).^(1/2) *(m/mp)^(1/2)
p1_rms = 5.057163286675063
Ω1 = 0.12 * (1 .- q.^2) ./ (1 .+ q^2)

m_ncdms = 1e-6*1.75*5.3^(4/3).*sqrt.(Ω1/Ω*p1_rms^2 .*T1_ncdm.^2 .+ Ω2/Ω*p2_rms^2 .*T2_ncdm.^2)
s = 0.5 #Spin of DM particle
g = 1 #DOF of DM particle

#COMOLOGICAL PARAMETERS

#Specify one of the following three parameters:
β = nothing #Initial PBH density fraction. If set to nothing, f is used.
f = nothing #Initial PBH dark matter fraciton. If set to nothing then Ω_ncdm is used.
Ω_ncdm = 0.12 #If set to nothing, then it is computed.
md = nothing #If set to nothing, then it is computed whether there is matter domination phase.

Ω_dm = 0.1201075 #Total dark matter density

#PSD PARAMETERS

use_fits = falses(10) #Whether to use a PSD file or an analytical expression

n_e_class = 200 #Number of values for q=E/T for CLASS
q_min_class = 0.01 #Minimum value for q=E/T for CLASS
q_max_class = 100 #Maximum value for q=E/T for CLASS
#qs_max_class = [10,100,1000,10000,100000] 
n_e = 1000 #Number of values for q=E/T for plots and fitting
q_min = 1e-4 #Minimum value for q=E/T for plots and fitting
q_max = 1e4 #Maximum value for q=E/T for plots and fitting


#CONTRAINT PARAMETERS

area_crit = 0.34 #Area criterion threshold
max_iter = 6 #Maximum number of iterations
darea = 0.01 #Difference from Area criterion when to stop
# Out:
# 0.01

# %%
area_iter = zeros(length(m0s),max_iter)
m_ncdms_iter = zeros(length(m0s),max_iter)
m_ncdms_iter[:,1] = m_ncdms

pbhini = open("PBH.ini")
pbh_ini_string = read(pbhini,String)
close(pbhini)
run(`mkdir -p Plots`)
run(`mkdir -p Output`)


for i=1:length(m0s)
    for iter=1:max_iter
        if iter > 1
            if abs(area_iter[i,iter-1]-area_crit) > darea
                run_iteration = true
            else
                run_iteration = false
            end
        else
            run_iteration = true
        end
        
        if run_iteration
            parameters = []

            m0 = m0s[i]
            q = qs[i]
            k = ks[i]
            m_ncdm = m_ncdms_iter[i,iter]
            burst = bursts[i]
            use_fit = use_fits[i]

            println()
            println()
            println("m=",m0,"g, q=",q,", k=",k,", burst=",burst,", m_dm=",m_ncdm," GeV")

            T0 = bh_temp(m0)

            e = 10 .^ LinRange(log10(T0*q_min),log10(T0*q_max),n_e)
            e_class = 10 .^ LinRange(log10(T0*q_min_class),log10(T0*q_max_class),n_e_class)
            println(e_class[1:2])

            t_start = bh_formation(m0)
            if k > 0
                t_end = bh_lifetime_estimate(m0,a_bh,m_fin=q*m0)
            else
                t_end = bh_lifetime_estimate(m0,a_bh)
            end
            #t_end = bh_lifetime_estimate(m0,a_bh,k=k,burst=burst,q=q)

            β_c = t_to_a(t_start)/t_to_a(t_end)

            if isnothing(md)
                if !isnothing(β)
                    β_comp = β
                elseif !isnothing(f)
                    β_comp = β_fm(f_comp,m0)
                else
                    if burst
                        N_approx = 2.85e-2*m0^2/mp^2
                    else
                        N_approx = 2.85e-2*m0^2/mp^2 * (1+q^2)
                    end
                    f_comp = Ω_ncdm * m0 / (N_approx * m_ncdm * GeV_to_g * Ω_dm)
                    β_comp = β_fm(f_comp,m0)
                end
                if β_comp > β_c
                    md_comp = true
                else
                    md_comp = false
                end
            else
                md_comp = md
            end

            println()
            println("Matter domination: ",md_comp)
            println()
            println("First stage")

            a_end = t_to_a(t_end)
            #a_end = 2.2e-31 * (m0/mp)^(3/2)
            #a_end_approx = 3.33e-31 * (1-q^3)^(1/2)*(m0/mp)^(3/2)
            #println("aev_1 ",abs(1-a_end/a_end_approx))
            if md_comp
                a_end = a_end*(9/16)^(1/4)
            end

            T_ncdm = T0*GeV_to_K/2.7255*a_end
            println("T_ncdm ",T_ncdm)
            #T_ncdm_approx = 0.69054 * (1-0*q^3)^(1/2) *(m0/mp)^(1/2)
            #println("T_ncdm_approx ",T_ncdm_approx)



            Φ1, Φ2 = spectrum_redshift(e,m0,s,g,a_bh,
                t_start=t_start,t_end=t_end,go=false,k=k,burst=burst,q=q,instant=false,n_steps=1000,split_flux=true,md=md_comp)
            Φ1_class, Φ2_class = spectrum_redshift(e_class,m0,s,g,a_bh,
                t_start=t_start,t_end=t_end,go=false,k=k,burst=burst,q=q,instant=false,n_steps=1000,split_flux=true,md=md_comp)

            N1 = trapz(e,Φ1)
            println(N1)
            #N1_approx = 2.85e-2*m0^2/mp^2*(1-q^2)
            #println("N_1 ",abs(1-N1/N1_approx))

            if !isnothing(β)
                if β < β_c
                    Ω1 = N1 * m_ncdm * GeV_to_g * Ω_dm * f_βm(β,m0) / m0
                    if k > 0
                        Ω1_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * Ω_dm * f_βm(β,m0) * (1 - q^2)
                    else
                        Ω1_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * Ω_dm * f_βm(β,m0)
                    end
                    #println("Deviation of Ω_ncdm ",round(100*abs(1-Ω1_approx/Ω1),sigdigits=4)," %")
                else
                    Ω1 = Ω_dm * m_ncdm*1e3 / sqrt(m0/(1.1e7*mp)) * 2.85/3.2
                    if k > 0
                        Ω1 *= (1-q^2)
                    end
                end
            elseif !isnothing(f)
                Ω1 = N1 * m_ncdm * GeV_to_g * Ω_dm * f / m0
                if k > 0
                    Ω1_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * Ω_dm * f * (1 - q^2)
                else
                    Ω1_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * Ω_dm * f
                end
                #println("Deviation of Ω_ncdm ",round(100*abs(1-Ω1_approx/Ω1),sigdigits=4)," %")
            elseif burst
                if k > 0
                    Ω1 = Ω_ncdm * (1-q^2)
                else 
                    Ω1 = Ω_ncdm
                end
                f_check = Ω1 * m0 / (N1 * m_ncdm * GeV_to_g * Ω_dm)
                if abs(1-f_check/f_comp) > 1e-3
                    throw(ArgumentError("Something with the PBH abundance is not right..."))
                end
                println("f_PBH: ",f_comp)
            else
                if k > 0
                    Ω1 = Ω_ncdm * (1-q^2)/(1+q^2)
                else
                    Ω1 = Ω_ncdm
                end
                f_check = Ω1 * m0 / (N1 * m_ncdm * GeV_to_g * Ω_dm)
                if abs(1-f_check/f_comp) > 1e-3
                    throw(ArgumentError("Something with the PBH abundance is not right..."))
                end
                println("f_PBH: ",f_comp)
            end

            if bh_lifetime_estimate(m0,k=k,burst=burst,q=q) > 1 && f_comp > 1
                println("Ω_PBH>1 today!")
            end

            println("Ω_ncdm ",Ω1)

            if use_fit
                ff(x,a,b,c,d,e) = spectrum_redshift_approximation.(x,bh_lifetime_estimate(m0,a_bh,m_fin=q*m0),bh_lifetime_estimate(m0,a_bh,k=k,burst=burst,q=q),a,b,c,d,e)
                fit = optimize.curve_fit(ff,e/T0,Φ1*T0^3/(mp*g_to_GeV)^2,[1,1,1,1,1])
                Φ_fit = ff.(e/T0,fit[1]...)


                p_mean = trapz(e/T0,e/T0 .* Φ1)/trapz(e/T0,Φ1)
                println("Mean momentum: ",p_mean)
                p_mean_approx = trapz(e/T0,e/T0  .* Φ_fit)/trapz(e/T0,Φ_fit)
                p_mean1_err = round(100*abs(1-p_mean_approx/p_mean),sigdigits=4)
                println("Deviation of mean momentum: ",p_mean1_err," %")

                p_rms = sqrt(trapz(e/T0,(e/T0).^2 .* Φ1)/trapz(e/T0,Φ1))
                println("RMS momentum: ",p_rms)
                p_rms_approx = sqrt(trapz(e/T0,(e/T0).^2  .* Φ_fit)/trapz(e/T0,Φ_fit))
                p_rms1_err = round(100*abs(1-p_rms_approx/p_rms),sigdigits=4)
                println("Deviation of rms momentum: ",p_rms1_err," %")
                flush(stdout)
            else
                fit = [[0,0,0,0,0]]
            end

            writedlm(string("Input/psd_",i,"_sc.dat"),[e_class/T0 (T0^3/(mp*g_to_GeV)^2)*Φ1_class/1.0./ (e_class/T0).^2])

            if two_stages && k > 0

                println()
                println("Second stage")

                T0 = T0/q

                t_end2 = bh_lifetime_estimate(m0,a_bh,k=k,burst=burst,q=q)

                a_end2 = t_to_a(t_end2)
                #if burst
                #    a_end2_approx = 3.336e-31 * 12.567^(k/2) * q^(3/2+k) * (m0/mp)^(3/2+k) / sqrt(1+2/3*k)
                #else
                #    a_end2_approx = 3.336e-31 * 12.567^(k/2) * q^(3/2+k) * (m0/mp)^(3/2+k) * sqrt(3)
                #end
                #println("aev_2 ",abs(1-a_end2/a_end2_approx))
                if md_comp
                    a_end2 = a_end2*(9/16)^(1/4)
                end


                T_ncdm2 = T0*GeV_to_K/2.7255*a_end2
                println("T_ncdm2 ",T_ncdm2)
                #if burst
                #    T_ncdm2_approx = 0.6905 * 12.567^(k/2) * q^(1/2+k) * (m0/mp)^(1/2 + k) / sqrt(1 + 2/3*k)
                #else
                #    T_ncdm2_approx = 0.6905 * 12.567^(k/2) * q^(1/2+k) * (m0/mp)^(1/2 + k) * sqrt(3)
                #end
                #println("Tncdm_2 ",abs(1-T_ncdm2/T_ncdm2_approx))


                Φ1, Φ2 = spectrum_redshift(e,m0,s,g,a_bh,
                    t_start=t_start,t_end=t_end2,go=false,k=k,burst=burst,q=q,instant=false,n_steps=1000,split_flux=true,md=md_comp)
                Φ1_class, Φ2_class = spectrum_redshift(e_class,m0,s,g,a_bh,
                    t_start=t_start,t_end=t_end2,go=false,k=k,burst=burst,q=q,instant=false,n_steps=1000,split_flux=true,md=md_comp)


                N2 = trapz(e,Φ2)
                #if burst
                #    N2_approx = 2.85e-2*m0^2/mp^2*q^2
                #else
                #    N2_approx = 2.85e-2*2*m0^2/mp^2*q^2
                #end
                #Ntot_approx = 2.85e-2*m0^2/mp^2*(1+q^2)

                if !isnothing(β)
                    if β < β_c
                        Ω2 = N2 * m_ncdm * GeV_to_g * 0.26 * f_βm(β,m0) / m0
                        Ω2_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * 0.26 * f_βm(β,m0) * q^2
                        if !burst
                            Ω2_approx *= 2
                        end
                        #println("Deviation of Ω_ncdm ",round(100*abs(1-Ω1_approx/Ω1),sigdigits=4)," %")
                    else
                        Ω2 = Ω_dm * m_ncdm*1e3 / sqrt(m0/(1.1e7*mp)) * 2.85/3.2 * q^2
                        if !burst
                            Ω2 *= 2
                        end
                    end
                elseif !isnothing(f)
                    Ω2 = N2 * m_ncdm * GeV_to_g * 0.26 * f / m0
                    Ω2_approx = 2.85e-2 * m0 * m_ncdm*GeV_to_g / mp^2 * 0.26 * f * q^2
                    if !burst
                        Ω2_approx *= 2
                    end
                    #println("Deviation of Ω_ncdm ",round(100*abs(1-Ω1_approx/Ω1),sigdigits=4)," %")
                elseif burst
                    Ω2 = Ω_ncdm * q^2
                    #Ω2 = Ω_ncdm
                else
                    Ω2 = 2 * Ω_ncdm * q^2/(1+q^2)
                    #Ω2 = Ω_ncdm
                end

                println("Ω_ncdm2 ",Ω2)

                if use_fit
                    ff2(x,a,b,c,d,e) = spectrum_redshift_approximation.(x,bh_lifetime_estimate(m0,a_bh,m_fin=q*m0),bh_lifetime_estimate(m0,a_bh,k=k,burst=burst,q=q),a,b,c,d,e)
                    fit2 = optimize.curve_fit(ff2,e/T0,Φ2*T0^3/(mp*g_to_GeV)^2,[1,1,1,1,1])
                    Φ_fit2 = ff2.(e/T0,fit2[1]...)

                    p_mean2 = trapz(e/T0,e/T0 .* Φ2)/trapz(e/T0,Φ2)
                    println("Mean momentum: ",p_mean2)
                    println(a_end2/(Ω_r_fid/Ω_m_fid))
                    println(1e4*a_end2/(Ω_r_fid/Ω_m_fid)*T0*p_mean2)
                    p_mean_approx2 = trapz(e/T0,e/T0  .* Φ_fit2)/trapz(e/T0,Φ_fit2)
                    p_mean_err2 = round(100*abs(1-p_mean_approx2/p_mean2),sigdigits=4)
                    println("Deviation of mean momentum: ",p_mean_err2," %")

                    p_rms2 = sqrt(trapz(e/T0,(e/T0).^2 .* Φ2)/trapz(e/T0,Φ2))
                    println("RMS momentum: ",p_rms2)
                    p_rms_approx2 = sqrt(trapz(e/T0,(e/T0).^2  .* Φ_fit2)/trapz(e/T0,Φ_fit2))
                    p_rms_err2 = round(100*abs(1-p_rms_approx2/p_rms2),sigdigits=4)
                    println("Deviation of rms momentum: ",p_rms_err2," %")
                    flush(stdout)
                else
                    fit2 = [[0,0,0,0,0]]
                end
                writedlm(string("Input/psd_",i,"_mb.dat"),[e_class/T0 (T0^3/(mp*g_to_GeV)^2)*Φ2_class ./(e_class/T0).^2])

                push!(parameters,"NNCDM"=>"2")
                push!(parameters,"DEGNCDM"=>"1,1")
                push!(parameters,"MNCDM"=>string(m_ncdm*1e9,",",m_ncdm*1e9))
                push!(parameters,"TNCDM"=>string(T_ncdm,",",T_ncdm2))
                push!(parameters,"OMEGANCDM"=>string(Ω1,",",Ω2))
                push!(parameters,"OMEGACDM"=>string(Ω_dm-Ω1-Ω2))
                push!(parameters,"FITPARAMS"=>string(fit[1][1],",",fit[1][2],",",fit[1][3],",",fit[1][4],",",fit[1][5],
            ",",fit2[1][1],",",fit2[1][2],",",fit2[1][3],",",fit2[1][4],",",fit2[1][5]))
                push!(parameters,"PSDFILE"=>string("../Input/psd_",i,"_sc.dat,../Input/psd_",i,"_mb.dat"))
                println("Using psd file")
                if use_fit
                    println("Using fit")
                    push!(parameters,"USEFILE"=>"0,0")
                else
                    println("Using psd file")
                    push!(parameters,"USEFILE"=>"1,1")
                end
            else
                push!(parameters,"NNCDM"=>"1")
                push!(parameters,"DEGNCDM"=>"1")
                push!(parameters,"MNCDM"=>string(m_ncdm*1e9))
                push!(parameters,"TNCDM"=>string(T_ncdm))
                push!(parameters,"OMEGANCDM"=>string(Ω1))
                push!(parameters,"OMEGACDM"=>string(Ω_dm-Ω1))
                push!(parameters,"FITPARAMS"=>string(fit[1][1],",",fit[1][2],",",fit[1][3],",",fit[1][4],",",fit[1][5]))
                push!(parameters,"PSDFILE"=>string("../Input/psd_",i,"_sc.dat"))
                if use_fit
                    println("Using fit")
                    push!(parameters,"USEFILE"=>"0")
                else
                    println("Using psd file")
                    push!(parameters,"USEFILE"=>"1")
                end
            end

            push!(parameters,"OUTPUTNAME"=>string(i))

            println()
            println("Running CLASS...")

            pbh_ini_string_mod = replace(pbh_ini_string,parameters...)
            open(string("Input/PBH_",i,".ini"), "w") do file
                write(file,pbh_ini_string_mod)
            end

            run(`./run.sh $(i)`)

            println("Computing area criterium...")
            data_cdm = readdlm("Data/CDM00_pk.dat",skipstart=4)
            data_pbh = readdlm(string("Output/",i,"_pk.dat"),skipstart=4)
            cdm_interp = linear_interpolation(log.(data_cdm[:,1]),log.(data_cdm[:,2].*data_cdm[:,1]))
            pbh_interp = linear_interpolation(log.(data_pbh[:,1]),log.(data_pbh[:,2].*data_pbh[:,1]));
            k_ev = 10 .^ LinRange(log10(0.5),log10(20),1000)
            cdm_int = zeros(length(k_ev))
            pbh_int = zeros(length(k_ev))

            for i=1:length(k_ev)
                k_int = 10 .^ LinRange(log10(k_ev[i]),log10(500),1000)
                cdm_int[i] = trapz(k_int,exp.(cdm_interp(log.(k_int))))
                pbh_int[i] = trapz(k_int,exp.(pbh_interp(log.(k_int))))
            end
            area_iter[i,iter] = 1 - trapz(k_ev,pbh_int ./ cdm_int)/trapz(k_ev,cdm_int ./ cdm_int)
            println("Area: ",area_iter[i,iter])
            println()
            println("-----------------------------------------------")
            println()

            if iter == 1
                if area_iter[i,iter] < area_crit
                    m_ncdms_iter[i,iter+1] = m_ncdms_iter[i,iter]/1.5
                else
                    m_ncdms_iter[i,iter+1] = m_ncdms_iter[i,iter]*1.5
                end
            elseif iter < max_iter
                m_ncdms_iter[i,iter+1] = m_ncdms_iter[i,iter-1]+(m_ncdms_iter[i,iter]-m_ncdms_iter[i,iter-1])/(area_iter[i,iter]-area_iter[i,iter-1])*(area_crit-area_iter[i,iter-1])
            end
        elseif iter < max_iter
            area_iter[i,iter] = area_iter[i,iter-1]
            m_ncdms_iter[i,iter+1] = m_ncdms_iter[i,iter]
        end
    end
end
# Out:
# m=10.0g, q=0.5, k=0.01, burst=false, m_dm=0.04559857906973137 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.6343059262255528e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1095.132923958517
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_1_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.559858e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000121862
#  -> ncdm species i=2 read from file ../Input/psd_1_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.559858e+07 eV (so m_i / omega_i =4.191517e-06 eV)
#  -> ncdm species i=2 sampled with 33 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000184347
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04431 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775378
#     corresponding to conformal time = 280.649976 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129509
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921963
#     corresponding to conformal time = 286.316085 Mpc
#     with comoving sound horizon rs = 147.071367 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.826499 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.823084 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/1_...
# Computing area criterium...
# Area: 0.3287697514312029
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.01, burst=false, m_dm=0.030399052713154243 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 2.4514588893383292e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1095.132923958517
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_1_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 3.039905e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000182793
#  -> ncdm species i=2 read from file ../Input/psd_1_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 3.039905e+07 eV (so m_i / omega_i =4.191517e-06 eV)
#  -> ncdm species i=2 sampled with 33 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.00027652
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897988 Mpc
#  -> N_eff = 3.04446 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751066
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775457
#     corresponding to conformal time = 280.649960 Mpc
#     with comoving sound horizon = 144.510113 Mpc
#     angular diameter distance = 12.728538 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129611
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.922041
#     corresponding to conformal time = 286.316068 Mpc
#     with comoving sound horizon rs = 147.071360 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540387 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.826497 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.823083 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/1_...
# Computing area criterium...
# Area: 0.4355711359645231
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.01, burst=false, m_dm=0.0440003370632423 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.693669480168183e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1095.132923958517
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_1_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.400034e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000126289
#  -> ncdm species i=2 read from file ../Input/psd_1_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.400034e+07 eV (so m_i / omega_i =4.191517e-06 eV)
#  -> ncdm species i=2 sampled with 33 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000191043
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04432 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775372
#     corresponding to conformal time = 280.649977 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129537
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921989
#     corresponding to conformal time = 286.316079 Mpc
#     with comoving sound horizon rs = 147.071365 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.826499 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.823084 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/1_...
# Computing area criterium...
# Area: 0.3374808354645906
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.01, burst=false, m_dm=0.04365102756988638 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.7072227654163422e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1095.132923958517
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_1_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.365103e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000127299
#  -> ncdm species i=2 read from file ../Input/psd_1_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.365103e+07 eV (so m_i / omega_i =4.191517e-06 eV)
#  -> ncdm species i=2 sampled with 33 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000192572
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04432 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775391
#     corresponding to conformal time = 280.649974 Mpc
#     with comoving sound horizon = 144.510120 Mpc
#     angular diameter distance = 12.728538 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129526
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921971
#     corresponding to conformal time = 286.316083 Mpc
#     with comoving sound horizon rs = 147.071367 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.826499 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.823085 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/1_...
# Computing area criterium...
# Area: 0.3394730116625623
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.01, burst=false, m_dm=0.04355862508593829 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.7108443587027688e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1095.132923958517
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_1_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.355863e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000127569
#  -> ncdm species i=2 read from file ../Input/psd_1_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.355863e+07 eV (so m_i / omega_i =4.191517e-06 eV)
#  -> ncdm species i=2 sampled with 33 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.00019298
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04432 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775374
#     corresponding to conformal time = 280.649977 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129524
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921974
#     corresponding to conformal time = 286.316082 Mpc
#     with comoving sound horizon rs = 147.071366 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.826499 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.823085 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/1_...
# Computing area criterium...
# Area: 0.3399858631843884
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.01, burst=false, m_dm=0.04355607800004298 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.7109444059920386e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1095.132923958517
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_1_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.355608e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000127577
#  -> ncdm species i=2 read from file ../Input/psd_1_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.355608e+07 eV (so m_i / omega_i =4.191517e-06 eV)
#  -> ncdm species i=2 sampled with 33 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000192992
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04432 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775362
#     corresponding to conformal time = 280.649979 Mpc
#     with comoving sound horizon = 144.510122 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129515
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921964
#     corresponding to conformal time = 286.316084 Mpc
#     with comoving sound horizon rs = 147.071367 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.826499 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.823085 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/1_...
# Computing area criterium...
# Area: 0.3400126701217998
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.042222222222222223, burst=false, m_dm=0.05235850992587815 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.4233030715851976e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1343.715193957545
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_2_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 5.235851e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000106129
#  -> ncdm species i=2 read from file ../Input/psd_2_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 5.235851e+07 eV (so m_i / omega_i =2.269078e-06 eV)
#  -> ncdm species i=2 sampled with 40 (resp. 11) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000182713
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04429 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775355
#     corresponding to conformal time = 280.649981 Mpc
#     with comoving sound horizon = 144.510123 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129507
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921961
#     corresponding to conformal time = 286.316085 Mpc
#     with comoving sound horizon rs = 147.071368 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.824134 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.820732 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/2_...
# Computing area criterium...
# Area: 0.3199214954409223
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.042222222222222223, burst=false, m_dm=0.03490567328391877 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 2.1349546073777964e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1343.715193957545
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_2_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 3.490567e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000159193
#  -> ncdm species i=2 read from file ../Input/psd_2_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 3.490567e+07 eV (so m_i / omega_i =2.269078e-06 eV)
#  -> ncdm species i=2 sampled with 40 (resp. 11) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.00027407
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897988 Mpc
#  -> N_eff = 3.04443 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751066
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775430
#     corresponding to conformal time = 280.649965 Mpc
#     with comoving sound horizon = 144.510116 Mpc
#     angular diameter distance = 12.728538 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129591
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.922028
#     corresponding to conformal time = 286.316071 Mpc
#     with comoving sound horizon rs = 147.071361 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540387 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.824132 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.82073 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/2_...
# Computing area criterium...
# Area: 0.4238695241116388
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.042222222222222223, burst=false, m_dm=0.048987336229121554 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.5212508729312218e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1343.715193957545
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_2_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.898734e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000113432
#  -> ncdm species i=2 read from file ../Input/psd_2_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.898734e+07 eV (so m_i / omega_i =2.269078e-06 eV)
#  -> ncdm species i=2 sampled with 40 (resp. 11) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000195287
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04431 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775368
#     corresponding to conformal time = 280.649978 Mpc
#     with comoving sound horizon = 144.510122 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129502
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921950
#     corresponding to conformal time = 286.316087 Mpc
#     with comoving sound horizon rs = 147.071368 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.824134 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.820731 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/2_...
# Computing area criterium...
# Area: 0.33586986526955487
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.042222222222222223, burst=false, m_dm=0.04832643406248052 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.5420551804997244e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1343.715193957545
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_2_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.832643e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000114983
#  -> ncdm species i=2 read from file ../Input/psd_2_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.832643e+07 eV (so m_i / omega_i =2.269078e-06 eV)
#  -> ncdm species i=2 sampled with 40 (resp. 11) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000197958
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04431 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775382
#     corresponding to conformal time = 280.649975 Mpc
#     with comoving sound horizon = 144.510120 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129536
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921984
#     corresponding to conformal time = 286.316080 Mpc
#     with comoving sound horizon rs = 147.071365 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.824134 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.820732 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/2_...
# Computing area criterium...
# Area: 0.339184092763151
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.042222222222222223, burst=false, m_dm=0.048163731030883096 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.5472644333418046e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1343.715193957545
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_2_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.816373e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000115372
#  -> ncdm species i=2 read from file ../Input/psd_2_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.816373e+07 eV (so m_i / omega_i =2.269078e-06 eV)
#  -> ncdm species i=2 sampled with 40 (resp. 11) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000198627
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04431 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775378
#     corresponding to conformal time = 280.649976 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129529
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921974
#     corresponding to conformal time = 286.316082 Mpc
#     with comoving sound horizon rs = 147.071366 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.824134 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.820731 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/2_...
# Computing area criterium...
# Area: 0.3399749468373957
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.042222222222222223, burst=false, m_dm=0.0481585768240078 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.5474300304484086e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1343.715193957545
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_2_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.815858e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000115384
#  -> ncdm species i=2 read from file ../Input/psd_2_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.815858e+07 eV (so m_i / omega_i =2.269078e-06 eV)
#  -> ncdm species i=2 sampled with 40 (resp. 11) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000198648
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04431 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775370
#     corresponding to conformal time = 280.649978 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129508
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921958
#     corresponding to conformal time = 286.316086 Mpc
#     with comoving sound horizon rs = 147.071368 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.824134 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.820731 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/2_...
# Computing area criterium...
# Area: 0.3400339512802185
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.07444444444444444, burst=false, m_dm=0.06582743416024317 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.1320816153902958e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1806.3665063395886
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_3_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 6.582743e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 8.44137e-05
#  -> ncdm species i=2 read from file ../Input/psd_3_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 6.582743e+07 eV (so m_i / omega_i =9.338920e-07 eV)
#  -> ncdm species i=2 sampled with 21 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000179998
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04426 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775345
#     corresponding to conformal time = 280.649983 Mpc
#     with comoving sound horizon = 144.510124 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129487
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921949
#     corresponding to conformal time = 286.316088 Mpc
#     with comoving sound horizon rs = 147.071369 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825849 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822438 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/3_...
# Computing area criterium...
# Area: 0.30104449718343895
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.07444444444444444, burst=false, m_dm=0.04388495610682878 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.698122423085444e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1806.3665063395886
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_3_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 4.388496e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000126621
#  -> ncdm species i=2 read from file ../Input/psd_3_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 4.388496e+07 eV (so m_i / omega_i =9.338920e-07 eV)
#  -> ncdm species i=2 sampled with 21 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000269997
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897988 Mpc
#  -> N_eff = 3.0444 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751066
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775420
#     corresponding to conformal time = 280.649967 Mpc
#     with comoving sound horizon = 144.510117 Mpc
#     angular diameter distance = 12.728538 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129569
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.922007
#     corresponding to conformal time = 286.316075 Mpc
#     with comoving sound horizon rs = 147.071363 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540387 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825847 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822436 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/3_...
# Computing area criterium...
# Area: 0.40153087263402365
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.07444444444444444, burst=false, m_dm=0.05732100468879247 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.3000823765340794e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1806.3665063395886
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_3_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 5.732100e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 9.69407e-05
#  -> ncdm species i=2 read from file ../Input/psd_3_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 5.732100e+07 eV (so m_i / omega_i =9.338920e-07 eV)
#  -> ncdm species i=2 sampled with 21 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.00020671
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.0443 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775380
#     corresponding to conformal time = 280.649976 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129532
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921981
#     corresponding to conformal time = 286.316081 Mpc
#     with comoving sound horizon rs = 147.071366 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825848 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822437 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/3_...
# Computing area criterium...
# Area: 0.3335310068846379
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.07444444444444444, burst=false, m_dm=0.056042800609761925 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.329734188696945e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1806.3665063395886
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_3_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 5.604280e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 9.91517e-05
#  -> ncdm species i=2 read from file ../Input/psd_3_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 5.604280e+07 eV (so m_i / omega_i =9.338920e-07 eV)
#  -> ncdm species i=2 sampled with 21 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000211424
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04431 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775373
#     corresponding to conformal time = 280.649977 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129491
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921948
#     corresponding to conformal time = 286.316088 Mpc
#     with comoving sound horizon rs = 147.071369 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825848 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822437 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/3_...
# Computing area criterium...
# Area: 0.3389261206302152
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.07444444444444444, burst=false, m_dm=0.055788378357409796 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.3357984260395416e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1806.3665063395886
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_3_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 5.578838e+07 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 9.96039e-05
#  -> ncdm species i=2 read from file ../Input/psd_3_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 5.578838e+07 eV (so m_i / omega_i =9.338920e-07 eV)
#  -> ncdm species i=2 sampled with 21 (resp. 13) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000212389
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04431 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775377
#     corresponding to conformal time = 280.649976 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129533
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921981
#     corresponding to conformal time = 286.316081 Mpc
#     with comoving sound horizon rs = 147.071366 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825848 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.822437 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/3_...
# Computing area criterium...
# Area: 0.34010607638007107
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.07444444444444444, burst=false, m_dm=0.055811250563882225 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.3352509977504918e16
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 1806.3665063395886
# Ω_ncdm2 0.048
# Using psd file
# ...
#  -> ncdm species i=2 read from file ../Input/psd_10_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 1.125216e+09 eV (so m_i / omega_i =1.396176e-10 eV)
#  -> ncdm species i=2 sampled with 245 (resp. 18) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000171389
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04418 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751108
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775315
#     corresponding to conformal time = 280.649989 Mpc
#     with comoving sound horizon = 144.510127 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129451
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921916
#     corresponding to conformal time = 286.316094 Mpc
#     with comoving sound horizon rs = 147.071372 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825255 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821846 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/10_...
# Computing area criterium...
# Area: 0.2462029995740519
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.3, burst=false, m_dm=0.7501441970212088 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 9.934360393248428e14
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 34036.334399530584
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_10_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 7.501442e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 7.40756e-06
#  -> ncdm species i=2 read from file ../Input/psd_10_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 7.501442e+08 eV (so m_i / omega_i =1.396176e-10 eV)
#  -> ncdm species i=2 sampled with 245 (resp. 18) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000257083
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897989 Mpc
#  -> N_eff = 3.04426 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751066
#     corresponding to conformal time = 112.722902 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775358
#     corresponding to conformal time = 280.649980 Mpc
#     with comoving sound horizon = 144.510122 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129482
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921941
#     corresponding to conformal time = 286.316089 Mpc
#     with comoving sound horizon rs = 147.071369 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825254 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821846 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/10_...
# Computing area criterium...
# Area: 0.32938085099296166
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.3, burst=false, m_dm=0.7022594965327662 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.0611750836985565e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 34036.334399530584
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_10_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 7.022595e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 7.91266e-06
#  -> ncdm species i=2 read from file ../Input/psd_10_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 7.022595e+08 eV (so m_i / omega_i =1.396176e-10 eV)
#  -> ncdm species i=2 sampled with 245 (resp. 18) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000274613
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897988 Mpc
#  -> N_eff = 3.04428 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751066
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775368
#     corresponding to conformal time = 280.649978 Mpc
#     with comoving sound horizon = 144.510121 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129494
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921947
#     corresponding to conformal time = 286.316087 Mpc
#     with comoving sound horizon rs = 147.071368 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540387 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825254 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821846 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/10_...
# Computing area criterium...
# Area: 0.3441769050568466
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.3, burst=false, m_dm=0.7157772795005884 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.0411343044182944e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 34036.334399530584
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_10_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 7.157773e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 7.76322e-06
#  -> ncdm species i=2 read from file ../Input/psd_10_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 7.157773e+08 eV (so m_i / omega_i =1.396176e-10 eV)
#  -> ncdm species i=2 sampled with 245 (resp. 18) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000269427
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897988 Mpc
#  -> N_eff = 3.04428 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751066
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775352
#     corresponding to conformal time = 280.649981 Mpc
#     with comoving sound horizon = 144.510123 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129476
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921935
#     corresponding to conformal time = 286.316090 Mpc
#     with comoving sound horizon rs = 147.071369 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825254 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821846 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/10_...
# Computing area criterium...
# Area: 0.33995464951409127
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.3, burst=false, m_dm=0.7156320874297173 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.0413455364862365e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 34036.334399530584
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_10_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 7.156321e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 7.7648e-06
#  -> ncdm species i=2 read from file ../Input/psd_10_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 7.156321e+08 eV (so m_i / omega_i =1.396176e-10 eV)
#  -> ncdm species i=2 sampled with 245 (resp. 18) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000269481
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897988 Mpc
#  -> N_eff = 3.04428 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751066
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775352
#     corresponding to conformal time = 280.649981 Mpc
#     with comoving sound horizon = 144.510123 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129483
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921938
#     corresponding to conformal time = 286.316089 Mpc
#     with comoving sound horizon rs = 147.071369 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825254 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821846 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/10_...
# Computing area criterium...
# Area: 0.3399684279492573
#
# -----------------------------------------------
#
#
#
# m=10.0g, q=0.5, k=0.3, burst=false, m_dm=0.7152993927968546 GeV
# [1.0579000000000004e10, 1.1080136729513012e10]
#
# Matter domination: false
#
# First stage
# T_ncdm 438.03184237994986
# 4.511946692326859e9
# f_PBH: 1.0418298792305941e15
# Ω_ncdm 0.072
#
# Second stage
# T_ncdm2 34036.334399530584
# Ω_ncdm2 0.048
# Using psd file
# Using psd file
#
# Running CLASS...
# Reading input parameters
#  -> matched budget equations by adjusting Omega_Lambda = 0.690026
# Running CLASS version v3.2.3
# Computing background
#  -> ncdm species i=1 read from file ../Input/psd_10_sc.dat
#  -> non-cold dark matter species with i=1 has m_i = 7.152994e+08 eV (so m_i / omega_i =1.746675e-04 eV)
#  -> ncdm species i=1 sampled with 16 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 7.76841e-06
#  -> ncdm species i=2 read from file ../Input/psd_10_mb.dat
#  -> non-cold dark matter species with i=2 has m_i = 7.152994e+08 eV (so m_i / omega_i =1.396176e-10 eV)
#  -> ncdm species i=2 sampled with 245 (resp. 18) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.000269607
#  -> age = 13.770598 Gyr
#  -> conformal age = 14151.897988 Mpc
#  -> N_eff = 3.04428 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3405.751066
#     corresponding to conformal time = 112.722901 Mpc
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2454
#  -> recombination (maximum of visibility function) at z = 1088.775359
#     corresponding to conformal time = 280.649979 Mpc
#     with comoving sound horizon = 144.510122 Mpc
#     angular diameter distance = 12.728539 Mpc
#     sound horizon angle 100*theta_s = 1.041796
#     Thomson optical depth crosses one at z_* = 1085.129498
#     giving an angle 100*theta_* = 1.044143
#  -> baryon drag stops at z = 1059.921954
#     corresponding to conformal time = 286.316086 Mpc
#     with comoving sound horizon rs = 147.071368 Mpc
#  -> reionization with optical depth = 0.054308
#     corresponding to conformal time = 5127.540388 Mpc
# Computing sources
# Computing primordial spectra (analytic spectrum)
# Computing linear Fourier spectra.
#  -> sigma8=0.825254 for total matter (computed till k = 504.931 h/Mpc)
#  -> sigma8=0.821846 for baryons+cdm  (computed till k = 504.931 h/Mpc)
# No non-linear spectra requested. Nonlinear calculations skipped.
# No harmonic space transfer functions to compute. Transfer module skipped.
# No spectra requested. Spectra module skipped.
# No lensing requested. Lensing module skipped.
# No distortions requested. Distortions module skipped.
# Writing output files in ../Output/10_...
# Computing area criterium...
# Area: 0.34005786445638964
#
# -----------------------------------------------

# %%
m_ncdms_iter
# Out:
# 10×6 Matrix{Float64}:
#  0.0455986  0.0303991  0.0440003  0.043651   0.0435586  0.0435561
#  0.0523585  0.0349057  0.0489873  0.0483264  0.0481637  0.0481586
#  0.0658274  0.043885   0.057321   0.0560428  0.0557884  0.0558113
#  0.0903322  0.0602215  0.0713991  0.0696498  0.069477   0.0694486
#  0.131753   0.0878354  0.0973923  0.0955158  0.095392   0.0953967
#  0.198677   0.132451   0.137589   0.13642    0.136398   0.136439
#  0.304355   0.202903   0.198728   0.19987    0.19974    0.199758
#  0.469493   0.312995   0.299817   0.303412   0.30336    0.303391
#  0.726378   0.484252   0.456454   0.464511   0.464353   0.46474
#  1.12522    0.750144   0.702259   0.715777   0.715632   0.715299

# %%
plot(ks,m_ncdms_iter[:,1] ./ m_ncdms_iter[:,end],".-",label="Estimate")
yscale("log")
xlabel(L"k")
ylabel(L"$m_{\rm DM}$ [GeV]")
legend()
# Out:
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x19ed945d0>

# %%
plot(ks,m_ncdms_iter[:,1],".-",label="Estimate")
plot(ks,m_ncdms_iter[:,end],".-",label="A=0.34")
yscale("log")
xlabel(L"k")
ylabel(L"$m_{\rm DM}$ [GeV]")
legend()
# Out:
# Figure(PyObject <Figure size 1200x900 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x19f1245d0>

# %%
writedlm("Output/area_crit.csv",[m0s ks qs bursts m_ncdms_iter[:,end] use_fits area_iter[:,end]])

# %%
[m0s ks qs bursts m_ncdms_iter[:,end] use_fits area_iter[:,end]]
# Out:
# 10×7 Matrix{Float64}:
#  10.0  0.01       0.5  0.0  0.0435561  0.0  0.340013
#  10.0  0.0422222  0.5  0.0  0.0481586  0.0  0.340034
#  10.0  0.0744444  0.5  0.0  0.0558113  0.0  0.339987
#  10.0  0.106667   0.5  0.0  0.0694486  0.0  0.339959
#  10.0  0.138889   0.5  0.0  0.0953967  0.0  0.339973
#  10.0  0.171111   0.5  0.0  0.136439   0.0  0.339961
#  10.0  0.203333   0.5  0.0  0.199758   0.0  0.340038
#  10.0  0.235556   0.5  0.0  0.303391   0.0  0.339984
#  10.0  0.267778   0.5  0.0  0.46474    0.0  0.339734
#  10.0  0.3        0.5  0.0  0.715299   0.0  0.340058

# %%
m_ncdms_iter
# Out:
# 10×6 Matrix{Float64}:
#  0.0455986  0.0303991  0.0440003  0.043651   0.0435586  0.0435561
#  0.0523585  0.0349057  0.0489873  0.0483264  0.0481637  0.0481586
#  0.0658274  0.043885   0.057321   0.0560428  0.0557884  0.0558113
#  0.0903322  0.0602215  0.0713991  0.0696498  0.069477   0.0694486
#  0.131753   0.0878354  0.0973923  0.0955158  0.095392   0.0953967
#  0.198677   0.132451   0.137589   0.13642    0.136398   0.136439
#  0.304355   0.202903   0.198728   0.19987    0.19974    0.199758
#  0.469493   0.312995   0.299817   0.303412   0.30336    0.303391
#  0.726378   0.484252   0.456454   0.464511   0.464353   0.46474
#  1.12522    0.750144   0.702259   0.715777   0.715632   0.715299

# %%
area_iter
# Out:
# 10×6 Matrix{Float64}:
#  0.32877   0.435571  0.337481  0.339473  0.339986  0.340013
#  0.319921  0.42387   0.33587   0.339184  0.339975  0.340034
#  0.301044  0.401531  0.333531  0.338926  0.340106  0.339987
#  0.279083  0.375964  0.333328  0.3394    0.339915  0.339959
#  0.267788  0.360084  0.335093  0.339696  0.340012  0.339973
#  0.257912  0.346904  0.337967  0.339962  0.339917  0.339961
#  0.249575  0.336425  0.341346  0.339826  0.340028  0.340038
#  0.248135  0.332865  0.342677  0.33996   0.340059  0.339984
#  0.246874  0.33041   0.343914  0.339922  0.339868  0.339734
#  0.246203  0.329381  0.344177  0.339955  0.339968  0.340058
